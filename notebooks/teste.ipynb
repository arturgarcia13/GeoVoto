# %%
import streamlit as st
import os
import pandas
from IPython.display import display
from pathlib import Path
import gdown
import geopandas as gpd


caminho_shp = "/workspaces/GeoVoto/bairros_fortaleza/vw_Fortaleza_Bairros.shp"
gdf_bairros = gpd.read_file(caminho_shp)
print(gdf_bairros.columns)
# Out:
# Index(['id', 'Nome', 'Código do', 'Código do0', 'Área (ha)', 'Regional A',
#        'Regional 0', 'Código da', 'Território', 'Fonte', 'ano_ref', 'data',
#        'epsg_codif', 'geometry'],
#       dtype='object')

# %%
import os 
print(os.getcwd())
# Out:
# /workspaces/GeoVoto/notebooks

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/lucassilva/Library/Mobile Documents/com~apple~CloudDocs/My_Projects/GeoVoto/GeoVoto/.venv/lib/python3.13/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/29/a2/d40fb2460e883eca5199c62cfc2463fd261f760556ae6290f88488c362c0/pip-25.1.1-py3-none-any.whl.metadata
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-25.1.1
